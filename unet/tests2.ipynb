# %%
import imp
import torch
import matplotlib.pyplot as plt
import model2

# %%
imp.reload(model2)
unetpp = model2.UNetPP()
garb = torch.randn([10, 12, 128, 128])
unetpp(garb).shape
# Out:
# torch.Size([10, 24, 64, 64])

# %%
plt.imshow(unetpp(garb[0].unsqueeze(0)).detach().squeeze()[23], cmap='viridis')
plt.show()

# %%
imp.reload(model2)
unetppmulti = model2.UNetPPDropoutMulti()
garbo = torch.randn([10, 12, 128, 128])
unetppmulti(garbo).shape
# Out:
# upped input shape: torch.Size([10, 128, 122, 122])
# PREVD (previous elem on diagonal: torch.Size([10, 128, 126, 126])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 128, 122, 122])
# upped input shape: torch.Size([10, 256, 56, 56])
# PREVD (previous elem on diagonal: torch.Size([10, 256, 61, 61])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 256, 56, 56])
# upped input shape: torch.Size([10, 512, 24, 24])
# PREVD (previous elem on diagonal: torch.Size([10, 512, 28, 28])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 512, 24, 24])
# upped input shape: torch.Size([10, 128, 108, 108])
# PREVD (previous elem on diagonal: torch.Size([10, 128, 120, 120])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 128, 108, 108])
# upped input shape: torch.Size([10, 256, 38, 38])
# PREVD (previous elem on diagonal: torch.Size([10, 256, 54, 54])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 256, 38, 38])
# upped input shape: torch.Size([10, 128, 72, 72])
# PREVD (previous elem on diagonal: torch.Size([10, 128, 106, 106])
# PREVD (previous elem on diagonal after crop: torch.Size([10, 128, 72, 72])
# torch.Size([10, 24, 64, 64])

# %%
plt.imshow(unetppmulti(garb[0].unsqueeze(0)).detach().squeeze()[23], cmap='viridis')
plt.show()
# Out:
# upped input shape: torch.Size([1, 128, 122, 122])
# PREVD (previous elem on diagonal: torch.Size([1, 128, 126, 126])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 128, 122, 122])
# upped input shape: torch.Size([1, 256, 56, 56])
# PREVD (previous elem on diagonal: torch.Size([1, 256, 61, 61])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 256, 56, 56])
# upped input shape: torch.Size([1, 512, 24, 24])
# PREVD (previous elem on diagonal: torch.Size([1, 512, 28, 28])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 512, 24, 24])
# upped input shape: torch.Size([1, 128, 108, 108])
# PREVD (previous elem on diagonal: torch.Size([1, 128, 120, 120])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 128, 108, 108])
# upped input shape: torch.Size([1, 256, 38, 38])
# PREVD (previous elem on diagonal: torch.Size([1, 256, 54, 54])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 256, 38, 38])
# upped input shape: torch.Size([1, 128, 72, 72])
# PREVD (previous elem on diagonal: torch.Size([1, 128, 106, 106])
# PREVD (previous elem on diagonal after crop: torch.Size([1, 128, 72, 72])
