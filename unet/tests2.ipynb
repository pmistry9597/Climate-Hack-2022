# %%
import imp
import torch
import matplotlib.pyplot as plt
import model2

# %%
imp.reload(model2)
unetpp = model2.UNetPP()
garb = torch.randn([10, 12, 128, 128])
unetpp(garb).shape
# Out:
# torch.Size([10, 24, 64, 64])

# %%
plt.imshow(unetpp(garb[0].unsqueeze(0)).detach().squeeze()[23], cmap='viridis')
plt.show()

# %%
imp.reload(model2)
unetppmulti = model2.UNetPPDropoutMultiBigBoi()
garbo = torch.randn([10, 12, 128, 128])
unetppmulti(garbo).shape
# Out:
# torch.Size([10, 24, 64, 64])

# %%
plt.imshow(unetppmulti(garbo[0].unsqueeze(0)).detach().squeeze()[23], cmap='viridis')
plt.show()
