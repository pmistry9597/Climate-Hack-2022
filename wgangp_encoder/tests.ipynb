# %%
import imp
import model
import torch
import matplotlib.pyplot as plt

# %%
imp.reload(model)
garbo = torch.randn([13, 1024, 1, 1])
garboOut = model.Decoder()
garbo = garboOut(garbo)
garbo.shape
# Out:
# torch.Size([13, 1, 128, 128])

# %%
for garb in garbo:
    plt.figure()
    plt.imshow(garb.detach().view([128,128]), cmap='viridis')
plt.show()

# %%
imp.reload(model)
garbo = torch.randn([23, 1, 128, 128])
garboIn = model.Encoder()
garboIn(garbo).shape
# Out:
# torch.Size([23, 1024, 1, 1])

# %%
imp.reload(model)
garbo = torch.randn([32,1,128,128])
critic = model.Critic()
critic(garbo).shape
# Out:
# torch.Size([32, 1024, 6, 6])
# torch.Size([32, 1])
